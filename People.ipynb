# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
# %matplotlib inline
import util, assign, grants, people, transactions, grantPlanning
import settings

# %%
import util, settings
util.print_settings()
run = util.run(settings.RUN_START, settings.RUN_END)
# Out:
# mygrantsjson is             toydata/mygrants.json  dated  Nov-22
# projects spreadsheet is     toydata/projects.xlsx
# people.json is              toydata/people.json
# assign.json is              toydata/assignFTE.json
# transactions spreadsheet is toydata/transactions.xlsx
# This run is from Jan-22 to Jan-23

# %%
gr = grants.grants(settings.MYGRANTS, settings.GRANTS_DATE)
gr.from_projects  (settings.PROJECTS)

# %%
pe = people.people(settings.PEOPLE, run)
print('People found:', pe.all_names())
# Restrict attention to just these
pe.set_names(['Bloggs', 'Jones'])
# Out:
# People found: ['Bloggs', 'Jones', 'Vivaldi']
# Restricting attention to  ['Bloggs', 'Jones']

# %%
an = assign.assign(settings.ASSIGN, gr, pe, run)
tr = transactions.transactions(settings.TRANSACTIONS, gr, pe, run)
gpa = grantPlanning.grants_people_assign(gr, pe, an, tr, run)

# %%
for person in gpa.people.people_name_set:
    gpa.plot_person(person)
